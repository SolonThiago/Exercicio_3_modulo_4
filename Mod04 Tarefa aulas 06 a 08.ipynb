# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)

# %%
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0      16682        Município  Mandaguaçu   4114104  PR    None
# 1      16691        Município  Ortigueira   4117305  PR    None
#
#                            status          num_processo        data_protocolo  \
# 0                    Regularizado  19406.000341/2006-44  2006-08-30T03:00:00Z
# 1  Arquivado por decurso de prazo  19406.000342/2008-51  2008-04-07T03:00:00Z
#
#                  tipo_operacao                                  finalidade  \
# 0  Operação contratual interna  Regularização de Dívida - Energia Elétrica
# 1  Operação contratual interna                              Infraestrutura
#
#                        tipo_credor  \
# 0                  Empresa Estatal
# 1  Instituição Financeira Nacional
#
#                                              credor moeda      valor  \
# 0                   Companhia Paranaense de Energia  Real  203655.93
# ...

# %%
df_rj_pvl = df[df['uf'] == 'RJ']
df_rj_pvl.head(2)
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 52       28489        Município  Rio de Janeiro   3304557  RJ
# 230       5734        Município  Rio de Janeiro   3304557  RJ
#
#                   num_pvl                          status  \
# 52   PVL02.000606/2018-62  Arquivado por decurso de prazo
# 230                  None                        Deferido
#
#              num_processo        data_protocolo                tipo_operacao  \
# 52   17944.104407/2018-95  2018-09-04T14:13:17Z  Operação contratual interna
# 230  17944.000185/2010-85  2010-10-18T02:00:00Z  Operação contratual interna
#
#                     finalidade                      tipo_credor  \
# 52     Renegociação de dívidas  Instituição Financeira Nacional
# 230  PAC - Copa Pró-Transporte  Instituição Financeira Nacional
#
#                                                 credor moeda         valor  \
# 52                             Caixa Econômica Federal  Real  4.416492e+08
# ...

# %%
# 2) Seu código aqui
df_rj_pvl.status.value_counts()
# Out:
# status
# Deferido                                                 28
# Arquivado                                                14
# Arquivado por decurso de prazo                           10
# Encaminhado à PGFN com manifestação técnica favorável    10
# Regularizado                                              8
# Deferido (PVL-IF)                                         3
# Arquivado a pedido                                        2
# Em retificação pelo interessado                           1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
status_ano = df_rj_pvl['data_status'].str.slice()
status_ano
# Out:
# 52      22/10/2019
# 230     01/12/2010
# 447     23/11/2023
# 958     20/01/2012
# 1084    07/06/2011
#            ...
# 4606    22/01/2013
# 4746    30/10/2008
# 4799    28/12/2016
# 4904    29/06/2012
# 4909    10/07/2012
# Name: data_status, Length: 76, dtype: object

# %%
# 4) Seu código aqui
status_ano.value_counts()
# Out:
# ano_status
# 2007    10
# 2008     9
# 2010     9
# 2012     7
# 2011     6
# 2023     5
# 2009     5
# 2020     4
# 2022     4
# 2013     4
# 2019     3
# 2016     2
# 2014     2
# 2015     2
# 2021     1
# 2018     1
# 2002     1
# 2006     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_dados(uf, tipo_interessado):
    dados_filtrados = df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)]
    return dados_filtrados

# %%
# teste
uf_consulta = 'PB'
tipo_interessado_consulta = 'Município' # consulta por 'Município' ou 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.head(3)
# Out:
#      id_pleito tipo_interessado  interessado  cod_ibge  uf num_pvl  \
# 856      18493        Município     Assunção   2501351  PB    None
# 972       5245        Município  João Pessoa   2507507  PB    None
# 974      10846        Município  Juripiranga   2507903  PB    None
#
#                              status          num_processo  \
# 856                        Deferido  19407.000034/2004-91
# 972  Arquivado por decurso de prazo  17944.000067/2015-81
# 974                       Arquivado  17944.001300/2008-14
#
#            data_protocolo                                      tipo_operacao  \
# 856  2004-05-24T03:00:00Z                        Operação contratual interna
# 972  2016-12-19T02:00:00Z  Operação contratual interna (com garantia da U...
# 974  2008-11-13T02:00:00Z                        Operação contratual interna
#
#                                             finalidade  \
# 856                                              PNAFM
# ...

# %%
# 2) Seu código aqui
uf_consulta = 'MG'
tipo_interessado_consulta = 'Estado' # consulta por 'Município' ou 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.head(3)
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 1116      20534           Estado  Minas Gerais        31  MG
# 1168      11328           Estado  Minas Gerais        31  MG
# 1569      13275           Estado  Minas Gerais        31  MG
#
#                    num_pvl                                             status  \
# 1116  00000.000000/2017-69                     Arquivado por decurso de prazo
# 1168                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1569                  None                                 Arquivado a pedido
#
#               num_processo        data_protocolo  \
# 1116  17944.001113/2015-60  2017-07-26T03:00:00Z
# 1168  17944.001412/2012-51  2012-12-11T02:00:00Z
# 1569  17944.002000/2013-10  2014-04-17T03:00:00Z
#
#                                           tipo_operacao      finalidade  \
# 1116                        Operação contratual interna            PMAE
# ...

# %%
status_MG = resultado_consulta['status'] == 'Arquivado por decurso de prazo'
status_MG.value_counts()
# Out:
# status
# False    7
# True     1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Município' # consulta por 'Município' ou 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.head(3)
# Out:
#      id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 237      26766        Município                Salvador   2927408  BA
# 381      33858        Município  Santo Antônio de Jesus   2928703  BA
# 409      30560        Município       Bom Jesus da Lapa   2903904  BA
#
#                   num_pvl             status          num_processo  \
# 237  PVL02.002104/2017-95           Deferido  17944.102830/2017-70
# 381  PVL02.002868/2019-42  Deferido (PVL-IF)                  None
# 409  PVL02.002971/2018-10  Deferido (PVL-IF)                  None
#
#            data_protocolo                tipo_operacao      finalidade  \
# 237  2017-12-19T21:42:07Z  Operação contratual interna  Infraestrutura
# 381                  None  Operação contratual interna  Infraestrutura
# 409                  None  Operação contratual interna  Infraestrutura
#
#                          tipo_credor  \
# 237  Instituição Financeira Nacional
# 381  Instituição Financeira Nacional
# ...

# %%
deferido = resultado_consulta[resultado_consulta['status'] == 'Deferido'] #Filtrando apenas os deferidos
deferido.head(3)
# Out:
#      id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 237      26766        Município    Salvador   2927408  BA
# 509      54329        Município       Irecê   2914604  BA
# 572      64288        Município   Itamaraju   2915601  BA
#
#                   num_pvl    status          num_processo  \
# 237  PVL02.002104/2017-95  Deferido  17944.102830/2017-70
# 509  PVL02.001295/2022-35  Deferido  17944.100706/2022-37
# 572  PVL02.001151/2023-60  Deferido  17944.101895/2023-46
#
#            data_protocolo                tipo_operacao      finalidade  \
# 237  2017-12-19T21:42:07Z  Operação contratual interna  Infraestrutura
# 509  2022-03-09T23:16:42Z  Operação contratual interna  Infraestrutura
# 572  2023-05-12T19:48:42Z  Operação contratual interna  Infraestrutura
#
#                          tipo_credor                   credor moeda  \
# 237  Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 509  Instituição Financeira Nacional  Caixa Econômica Federal  Real
# ...

# %%
deferido_por_municipio = deferido['interessado'].value_counts()
deferido_por_municipio.head()
# Out:
# interessado
# Salvador                  4
# Riachão do Jacuípe        3
# Luís Eduardo Magalhães    3
# Formosa do Rio Preto      3
# Nordestina                2
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.to_csv('Solicitações_Bahia.csv')
